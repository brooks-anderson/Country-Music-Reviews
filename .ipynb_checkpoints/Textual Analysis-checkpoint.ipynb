# %% [markdown]
# # Country & Soul
# ### *Analyzing Trends in American Music Journalism from 1960 to Present*
# ---

# %% [markdown]
# # Textual Analysis
# #### Table of Contents
# 1. [Introduction](#introduction)
# 2. [Vector Space Modeling](#paragraph1)
# 3. [Clustering](#paragraph2)
# 4. [Principal Component Analysis](#paragraph3)
# 5. [Topic Modeling](#paragraph4)
# 6. [Word Embeddings](#paragraph5)
# 7. [Sentiment Analysis](#paragraph6)

# %% [markdown]
# ## Introduction<a name="introduction"></a>
# In this notebook, I apply several analytical techniques to the corpus of music reviews. I employ vector space models (VSM), clustering methods, Principal Component Analysis (PCA), topic models, word embeddings, and semantic analysis.
#
# To begin, I read in the tables that I created in *`Digital Analytical Edition.ipynb`*.

# %%
# Libraries
import pandas as pd
import numpy as np
import plotly_express as px

from gensim.models import word2vec
from ast import literal_eval

import plotly.io as pio
pio.renderers.default='notebook'

# %%
# define OHCO structure
OHCO = ['article_id', 'para_id', 'sent_id', 'token_id']

# import data
path = "./data/"


LIB = pd.read_csv(path+"LIB.csv")
LIB.set_index('article_id', inplace = True)
LIB.subjects = LIB.subjects.apply(literal_eval)

VOCAB = pd.read_csv(path+"VOCAB.csv")
VOCAB.set_index('term_str', inplace = True)

CORPUS = pd.read_csv(path+"CORPUS.csv")
CORPUS.set_index(OHCO, inplace = True)

# %%
uBOW = pd.read_csv(path+"BOW_unigrams.csv")
uBOW.set_index(['article_id', 'term_str'], inplace = True)

nBOW = pd.read_csv(path+"BOW_ngrams.csv")
nBOW.set_index(['article_id', 'term_str'], inplace=True)

# %%
# Frequent artists by genre
from itertools import chain, count
soul_artists = list(chain.from_iterable(LIB[LIB.topic == 'soul'].subjects))
country_artists = list(chain.from_iterable(LIB[LIB.topic == 'country'].subjects))

top_soul_artists  = pd.DataFrame(soul_artists).value_counts().to_frame().head(5)
top_soul_artists.index.names = ['artist']
top_soul_artists.rename(columns = {0:'mentions'}, inplace = True)
top_country_artists = pd.DataFrame(country_artists).value_counts().to_frame().head(5)
top_country_artists.index.names = ['artist']
top_country_artists.rename(columns = {0:'mentions'}, inplace = True)

top_artists = top_soul_artists.append(top_country_artists)
# Out:
# C:\Users\brook\AppData\Local\Temp\ipykernel_8200\1307845292.py:13: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
top_artists = top_artists.reset_index().artist.to_list()

# %% [markdown]
# ---
# ## Vector Space Modeling<a name="paragraph1"></a>

# %% [markdown]
# Here, I create several vector space models (VSMs). The first VSM is a straightforward document-term matrix. This representation allows me to asses the similarity of documents in the corpus.
#
# The second VSM is a term-time matrix that measures term occurence over time. Terms are assigned a time step based on the order of their occurence in an article. Publication dates are used to order articles within the corpus.

# %%
# Creating the Doc-Term Matrix
DTM = uBOW.tfidf.unstack('term_str', 0)

# %%
from sklearn.decomposition import PCA

pca_engine = PCA(n_components = 2)

docPCs = pca_engine.fit_transform(DTM)
DOCTERMPC = pd.DataFrame(docPCs, index = DTM.index, columns = ['PC1', 'PC2'])
DOCTERMPC = DOCTERMPC.join(LIB)
# Out:
# C:\Users\brook\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['float', 'str']. An error will be raised in 1.2.

# %%
px.scatter(DOCTERMPC,
          x = 'PC1',
          y = 'PC2',
          color = 'topic')
# Out:
# <div>                            <div id="7f2df626-1430-4de4-9479-634262733cf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f2df626-1430-4de4-9479-634262733cf4")) {                    Plotly.newPlot(                        "7f2df626-1430-4de4-9479-634262733cf4",                        [{"hovertemplate":"topic=country<br>PC1=%{x}<br>PC2=%{y}<extra></extra>","legendgroup":"country","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"country","showlegend":true,"x":[-0.03910570882400558,-0.06331970713869883,-0.10817743165231217,0.2193288132594851,-0.09135655854542109,-0.09269794273720842,-0.02889724523484741,-0.11467922844568061,-0.025618733122317567,-0.10421093996953233,-0.010890777106179892,-0.07206587509464767,-0.05390896087065368,-0.0674577151818927,0.1617459037644798,-0.038532281463889144,0.29495521924930695,-0.008029480990326987,-0.0343970096813268,-0.024885986129878128,-0.03711326437032135,-0.05291442687744749,-0.07355063374875781,0.005705017114309909,0.06329225755021275,0.05914199619707573,0.06399505196954547,0.03374235088743292,0.022947502612303886,-0.04930277063865282,-0.051967304451389904,-0.05682159470713314,0.03863322163916829,-0.061511811555064154,-0.027941103486872725,0.12638096396433757,-0.08307604013931025,-0.022763454028513732,-0.106428149864795,0.018717150103920333,-0.04661218067599093,-0.04623906876227437,-0.07376233002387461,0.011105895023376035,-0.01870792256346618,0.16562340611858797,0.05446717067148483,-0.11350865905967822,0.08454951127106529,0.24403964943973994,-0.02366900649175458,0.06661773082055465,-0.09302086684646356,-0.08307145226923959,-0.052497488871600995,0.052551486630711366,-0.10651629056806551,0.0418845662304989,-0.08794896818486854,-0.03914241590657496,-0.09235398387727108,-0.09018329907067342,-0.042103315123396094,-0.06420449762063862,-0.002527287678683784,-0.022942675619419612,0.07946187302442576,-0.10025196376158238,0.012211574960300139,0.10743853097429182,-0.031134388421551168,0.04395145751029208,-0.025395645269429494,0.23965038978049918,-0.059922522012540204,0.08066940504009225,0.06053689168525762,-0.05426248800855898,0.21009077093922457,-0.05573346237213103,-0.08693521782307827,-0.0912377892820159,-0.08828101461793043,0.3242834104560233,-0.016700844141939758,-0.07771676215235834,0.20332268346908203,-0.09827032057851766,-0.07768004000777173,0.01910426898165892,0.058273878683426046,-0.014941461680430956,0.04413517230614021,-0.057910218528898855,0.1421150175579447,-0.06391793106035527,-0.10313395178360867,0.3536265250521404,0.04780421271515844,-0.017037045539141243,0.04795784224312735,-0.0603836436462016,-0.03450799706159628,0.17555540673492903,0.04300070232542295,-0.024737543821694154,-0.08358722129038319,0.0577154020224064,-0.07768115672577255,-0.06956398161456487,-0.014793167352784645,-0.05846671060152462,0.043272337489978045,-0.11419286071112979,-0.10226922069478005,-0.06714736731109038,0.019800679445811577,0.0027112109066309243,-0.03935248731128572,-0.0993134329306646,-0.0912629245371419,-0.10692255311063782,-0.11662490468916104,-0.09684015741246425,-0.0052274039152208785,-0.11164945950731275,-0.1037626759396852,-0.05849366530814657,-0.04417354229148112,-0.10921428228133301,0.2208277513418433,0.12134054221285243,0.06709967385167065,0.021005347522042646,-0.09054876091472606,-0.04148875382379734,0.06039520533056667,-0.015782704362708483,-0.06607792460622675,-0.05342627992615125,-0.07175950167619045,-0.0661522755943301,-0.05326064541232582,-0.11980280167982356,0.055330710620827284,0.06108002792294567,-0.07635140019636881,-0.0682490085195743,0.10287402830400301,-0.07338117324214398,-0.07497883027130066,-0.12438750238078013,0.06825489302821725,0.006113672075643659,0.05572790754102162,0.13000841195944082,-0.06263160144425017,0.08131 ...

# %% [markdown]
# ---
# ## Clustering<a name="paragraph2"></a>

# %% [markdown]
# ---
# ## Principal Component Analysis<a name="paragraph3"></a>

# %% [markdown]
# ---
# ## Topic Modeling<a name="paragraph4"></a>

# %% [markdown]
# ---
# ## Word Embeddings<a name="paragraph5"></a>

# %% [markdown]
# ---
# ## Semtiment Analysis<a name="paragraph6"></a>
